# %%
import caffe
import json
import numpy as np

# %%
import facenet
import os
import tensorflow as tf
import re

# %%
with open('tf_2_caffe_correspondances.json', 'r') as fp:
    correspondances = json.load(fp)

# %%
from facenet_caffe_definition import *
inc_resnet_v1 = InceptionV4()
network_definition = inc_resnet_v1.inception_v4_proto(64, 'TEST')
with open('facenet_test_clobotics.prototxt', 'w') as fp:
    fp.writelines(str(network_definition))

# %%
caffe_net = caffe.Net('/home/caffe/achu/tf_2_caffe/facenet_test_clobotics.prototxt', caffe.TEST)

# %%
def copy_params(tf_names, caffe_names, caffe_net, model_dir = '/home/caffe/achu/frozen_models/latest_ccna.pb'):
    with tf.Graph().as_default():
        with tf.Session() as sess:
            facenet.load_model(model_dir)
            all_tensors = tf.contrib.graph_editor.get_tensors(tf.get_default_graph())
            all_tensor_names = [tensor.name for tensor in all_tensors]
            features_tensor_index = all_tensor_names.index('InceptionResnetV1/Bottleneck/weights:0')
            features_value = all_tensors[features_tensor_index].eval()
            caffe_net.params['features'][0].data[...] = features_value.transpose((1,0))
            features_bn_1_index = all_tensor_names.index('InceptionResnetV1/Bottleneck/BatchNorm/moving_mean:0')
            features_bn_1_value = all_tensors[features_bn_1_index].eval()
            
            features_bn_2_index = all_tensor_names.index('InceptionResnetV1/Bottleneck/BatchNorm/moving_variance:0')
            features_bn_2_value = all_tensors[features_bn_2_index].eval() + 0.001
            caffe_net.params['features_bn'][1].data[...] = features_bn_2_value
            caffe_net.params['features_bn'][2].data[...] = np.ones(caffe_net.params['features_bn'][2].data.shape)
            features_bn_beta_index = all_tensor_names.index('InceptionResnetV1/Bottleneck/BatchNorm/beta:0')
            features_bn_beta_value = all_tensors[features_bn_beta_index].eval()
            
            new_mu_value = np.subtract(features_bn_1_value, np.multiply(features_bn_beta_value, np.sqrt(features_bn_2_value)))
            
            caffe_net.params['features_bn'][0].data[...] = new_mu_value
            
            for i in range(len(caffe_names)):
                caffe_name = caffe_names[i]
                tf_conv_layer_name = tf_names[i]+'/weights:0'
                tf_conv_name_index = all_tensor_names.index(tf_conv_layer_name)
                tf_conv_layer_tensor = all_tensors[tf_conv_name_index]
                print ('Copying ' + tf_conv_layer_tensor.name+' into '+caffe_name)
                conv_layer_value = tf_conv_layer_tensor.eval()
                print ('TF conv_layer shape: ', conv_layer_value.shape)
                print ('Caffe conv_layer shape: ', caffe_net.params[caffe_name][0].data.shape)
                #if (caffe_net.params[caffe_name][0].data.shape == conv_layer_value.transpose((3,2,1,0)).shape):
                #    caffe_net.params[caffe_name][0].data[...] = conv_layer_value.transpose((3,2,1,0))
                if (caffe_net.params[caffe_name][0].data.shape == conv_layer_value.transpose((3,2,0,1)).shape):
                    caffe_net.params[caffe_name][0].data[...] = conv_layer_value.transpose((3,2,0,1))
                else:
                    print ('Shape mismatch: ', caffe_name, caffe_net.params[caffe_name][0].data.shape, conv_layer_value.shape)
                
                if (re.match('InceptionResnetV1/Repeat_1/block17_\d+/Conv2d_1x1', tf_names[i].encode("ascii")) is None) and (re.match('InceptionResnetV1/Repeat/block35_\d/Conv2d_1x1', tf_names[i].encode("ascii")) is None) and (re.match('InceptionResnetV1/Block8/Conv2d_1x1', tf_names[i].encode("ascii")) is None) and (re.match('InceptionResnetV1/Repeat_2/block8_\d/Conv2d_1x1', tf_names[i].encode("ascii")) is None):
                    print (tf_names[i], ' copying BN layer params')
                    tf_bn_layer_name_1 = tf_names[i]+'/BatchNorm/moving_mean:0'
                    tf_bn_layer_name_2 = tf_names[i]+'/BatchNorm/moving_variance:0' #+0.001
                    #tf_bn_layer_name_3 to be set to one
                    #tf_scale_layer_name_1 to be set to one Gamma
                    tf_scale_layer_name_2 = tf_names[i]+'/BatchNorm/beta:0'
                    caffe_bn_layer_name = caffe_name + '_bn'
                    caffe_scale_layer_name = caffe_name + '_scale'


                    tf_bn_name_index_1 = all_tensor_names.index(tf_bn_layer_name_1)
                    tf_bn_name_index_2 = all_tensor_names.index(tf_bn_layer_name_2)
                    tf_scale_name_index_2 = all_tensor_names.index(tf_scale_layer_name_2)


                    tf_bn_layer_1_tensor = all_tensors[tf_bn_name_index_1]
                    tf_bn_layer_2_tensor = all_tensors[tf_bn_name_index_2]
                    tf_scale_layer_2_tensor = all_tensors[tf_scale_name_index_2]


                    bn_layer_1_value = tf_bn_layer_1_tensor.eval() #Mu
                    bn_layer_2_value = tf_bn_layer_2_tensor.eval() + 0.001 #Sigma
                    #print (bn_layer_2_value)
                    bn_layer_3_value = np.ones(caffe_net.params[caffe_bn_layer_name][2].data.shape)
                    #scale_layer_1_value = np.ones(caffe_net.params[caffe_scale_layer_name][0].data.shape)
                    scale_layer_2_value = tf_scale_layer_2_tensor.eval() #Beta
                    
                    new_mu_value = np.subtract(bn_layer_1_value, np.multiply(scale_layer_2_value, np.sqrt(bn_layer_2_value)))
                    #print (new_mu_value)
                    bn_layer_1_value = new_mu_value

                    #Actual copy operations

                    #print (caffe_net.params[caffe_bn_layer_name][0].data.shape, bn_layer_1_value.shape)
                    caffe_net.params[caffe_bn_layer_name][0].data[...] = bn_layer_1_value

                    #print (caffe_net.params[caffe_bn_layer_name][1].data.shape, bn_layer_2_value.shape)
                    caffe_net.params[caffe_bn_layer_name][1].data[...] = bn_layer_2_value

                    #print (caffe_net.params[caffe_bn_layer_name][2].data.shape, bn_layer_3_value.shape)
                    caffe_net.params[caffe_bn_layer_name][2].data[...] = bn_layer_3_value

                    #print (caffe_net.params[caffe_scale_layer_name][0].data.shape, scale_layer_1_value.shape)
                    #caffe_net.params[caffe_scale_layer_name][0].data[...] = scale_layer_1_value

                    #print (caffe_net.params[caffe_scale_layer_name][1].data.shape, scale_layer_2_value.shape)
                    #caffe_net.params[caffe_scale_layer_name][1].data[...] = scale_layer_2_value
                else:
                    tf_conv_layer_biases = tf_names[i]+'/biases:0'
                    tf_conv_biases_index = all_tensor_names.index(tf_conv_layer_biases)
                    tf_conv_layer_biases_tensor = all_tensors[tf_conv_biases_index]
                    print ('Copying Biases ' + tf_conv_layer_biases_tensor.name+' into '+caffe_name)
                    conv_layer_biases_value = tf_conv_layer_biases_tensor.eval()
                    caffe_net.params[caffe_name][1].data[...] = conv_layer_biases_value
            
            return caffe_net

# %%
new_caffe_net = copy_params(list(correspondances.keys()), list(correspondances.values()), caffe_net)
# Out:
# Model filename: /home/caffe/achu/frozen_models/latest_ccna.pb
# WARNING:tensorflow:From /home/caffe/achu/facenet/src/facenet.py:370: __init__ (from tensorflow.python.platform.gfile) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.gfile.GFile.
# Copying InceptionResnetV1/Repeat/block35_3/Branch_1/Conv2d_0b_3x3/weights:0 into inception_a3_3x3_b1
# ('TF conv_layer shape: ', (3, 3, 32, 32))
# ('Caffe conv_layer shape: ', (32, 32, 3, 3))
# (u'InceptionResnetV1/Repeat/block35_3/Branch_1/Conv2d_0b_3x3', ' copying BN layer params')
# Copying InceptionResnetV1/Repeat/block35_2/Branch_2/Conv2d_0a_1x1/weights:0 into inception_a2_1x1_b2
# ('TF conv_layer shape: ', (1, 1, 256, 32))
# ('Caffe conv_layer shape: ', (32, 256, 1, 1))
# (u'InceptionResnetV1/Repeat/block35_2/Branch_2/Conv2d_0a_1x1', ' copying BN layer params')
# Copying InceptionResnetV1/Repeat_1/block17_6/Conv2d_1x1/weights:0 into inception_b6_1x1_a
# ('TF conv_layer shape: ', (1, 1, 256, 896))
# ('Caffe conv_layer shape: ', (896, 256, 1, 1))
# Copying Biases InceptionResnetV1/Repeat_1/block17_6/Conv2d_1x1/biases:0 into inception_b6_1x1_a
# Copying InceptionResnetV1/Repeat_2/block8_2/Branch_1/Conv2d_0a_1x1/weights:0 into inception_c2_1x1_2
# ('TF conv_layer shape: ', (1, 1, 1792, 192))
# ('Caffe conv_layer shape: ', (192, 1792, 1, 1))
# (u'InceptionResnetV1/Repeat_2/block8_2/Branch_1/Conv2d_0a_1x1', ' copying BN layer params')
# Copying InceptionResnetV1/Conv2d_4a_3x3/weights:0 into conv5_3x3_s1
# ('TF conv_layer shape: ', (3, 3, 80, 192))
# ('Caffe conv_layer shape: ', (192, 80, 3, 3))
# (u'InceptionResnetV1/Conv2d_4a_3x3', ' copying BN layer params')
# Copying InceptionResnetV1/Mixed_7a/Branch_0/Conv2d_0a_1x1/weights:0 into reduction_b_3x3_reduce
# ('TF conv_layer shape: ', (1, 1, 896, 256))
# ('Caffe conv_layer shape: ', (256, 896, 1, 1))
# (u'InceptionResnetV1/Mixed_7a/Branch_0/Conv2d_0a_1x1', ' copying BN layer params')
# Copying InceptionResnetV1/Repeat/block35_2/Branch_2/Conv2d_0b_3x3/weights:0 into inception_a2_3x3_b2
# ('TF conv_layer shape: ', (3, 3, 32, 32))
# ('Caffe conv_layer shape: ', (32, 32, 3, 3))
# (u'InceptionResnetV1/Repeat/block35_2/Branch_2/Conv2d_0b_3x3', ' copying BN layer params')
# Copying InceptionResnetV1/Repeat_2/block8_1/Branch_1/Conv2d_0c_3x1/weights:0 into inception_c1_3x1_2
# ('TF conv_layer shape: ', (3, 1, 192, 192))
# ('Caffe conv_layer shape: ', (192, 192, 3, 1))
# (u'InceptionResnetV1/Repeat_2/block8_1/Branch_1/Conv2d_0c_3x1', ' copying BN layer params')
# Copying InceptionResnetV1/Repeat_1/block17_4/Branch_1/Conv2d_0a_1x1/weights:0 into inception_b4_1x7_2_reduce
# ('TF conv_layer shape: ', (1, 1, 896, 128))
# ('Caffe conv_layer shape: ', (128, 896, 1, 1))
# (u'InceptionResnetV1/Repeat_1/block17_4/Branch_1/Conv2d_0a_1x1', ' copying BN layer params')
# Copying InceptionResnetV1/Repeat_2/block8_1/Branch_1/Conv2d_0a_1x1/weights:0 into inception_c1_1x1_2
# ('TF conv_layer shape: ', (1, 1, 1792, 192))
# ('Caffe conv_layer shape: ', (192, 1792, 1, 1))
# (u'InceptionResnetV1/Repeat_2/block8_1/Branch_1/Conv2d_0a_1x1', ' copying BN layer params')
# Copying InceptionResnetV1/Repeat/block35_1/Conv2d_1x1/weights:0 into inception_a1_1x1
# ('TF conv_layer shape: ', (1, 1, 96, 256))
# ('Caffe conv_layer shape: ', (256, 96, 1, 1))
# Copying Biases InceptionResnetV1/Repeat/block35_1/Conv2d_1x1/biases:0 into inception_a1_1x1
# Copying InceptionResnetV1/Repeat_1/block17_6/Branch_1/Conv2d_0b_1x7/weights:0 into inception_b6_1x7_2
# ('TF conv_layer shape: ', (1, 7, 128, 128))
# ('Caffe conv_layer shape: ', (128, 128, 1, 7))
# (u'InceptionResnetV1/Repeat_1/block17_6/Branch_1/Conv2d_0b_1x7', ' copying BN layer params')
# Copying InceptionResnetV1/Conv2d_4b_3x3/weights:0 into conv6_3x3_s2
# ('TF conv_layer shape: ', (3, 3, 192, 256))
# ('Caffe conv_layer shape: ', (256, 192, 3, 3))
# (u'InceptionResnetV1/Conv2d_4b_3x3', ' copying BN layer params')
# Copying InceptionResnetV1/Repeat_2/block8_4/Branch_1/Conv2d_0c_3x1/weights:0 into inception_c4_3x1_2
# ('TF conv_layer shape: ', (3, 1, 192, 192))
# ('Caffe conv_layer shape: ', (192, 192, 3, 1))
# (u'InceptionResnetV1/Repeat_2/block8_4/Branch_1/Conv2d_0c_3x1', ' copying BN layer params')
# Copying InceptionResnetV1/Repeat_1/block17_7/Branch_1/Conv2d_0c_7x1/weights:0 into inception_b7_7x1_2
# ('TF conv_layer shape: ', (7, 1, 128, 128))
# ('Caffe conv_layer shape: ', (128, 128, 7, 1))
# (u'InceptionResnetV1/Repeat_1/block17_7/Branch_1/Conv2d_0c_7x1', ' copying BN layer params')
# Copying InceptionResnetV1/Repeat/block35_1/Branch_1/Conv2d_0a_1x1/weights:0 into inception_a1_1x1_b1
# ('TF conv_layer shape: ', (1, 1, 256, 32))
# ('Caffe conv_layer shape: ', (32, 256, 1, 1))
# (u'InceptionResnetV1/Repeat/block35_1/Branch_1/Conv2d_0a_1x1', ' copying BN layer params')
# Copying InceptionResnetV1/Block8/Conv2d_1x1/weights:0 into Block8_conv_1x1_3
# ('TF conv_layer shape: ', (1, 1, 384, 1792))
# ('Caffe conv_layer shape: ', (1792, 384, 1, 1))
# Copying Biases InceptionResnetV1/Block8/Conv2d_1x1/biases:0 into Block8_conv_1x1_3
# Copying InceptionResnetV1/Repeat/block35_3/Branch_2/Conv2d_0b_3x3/weights:0 into inception_a3_3x3_b2
# ('TF conv_layer shape: ', (3, 3, 32, 32))
# ('Caffe conv_layer shape: ', (32, 32, 3, 3))
# (u'InceptionResnetV1/Repeat/block35_3/Branch_2/Conv2d_0b_3x3', ' copying BN layer params')
# Copying InceptionResnetV1/Repeat/block35_3/Conv2d_1x1/weights:0 into inception_a3_1x1
# ('TF conv_layer shape: ', (1, 1, 96, 256))
# ('Caffe conv_layer shape: ', (256, 96, 1, 1))
# Copying Biases InceptionResnetV1/Repeat/block35_3/Conv2d_1x1/biases:0 into inception_a3_1x1
# Copying InceptionResnetV1/Repeat/block35_2/Branch_0/Conv2d_1x1/weights:0 into inception_a2_1x1_b0
# ('TF conv_layer shape: ', (1, 1, 256, 32))
# ('Caffe conv_layer shape: ', (32, 256, 1, 1))
# (u'InceptionResnetV1/Repeat/block35_2/Branch_0/Conv2d_1x1', ' copying BN layer params')
# Copying InceptionResnetV1/Repeat_1/block17_8/Branch_0/Conv2d_1x1/weights:0 into inception_b8_1x1
# ('TF conv_layer shape: ', (1, 1, 896, 128))
# ('Caffe conv_layer shape: ', (128, 896, 1, 1))
# (u'InceptionResnetV1/Repeat_1/block17_8/Branch_0/Conv2d_1x1', ' copying BN layer params')
# Copying InceptionResnetV1/Repeat_1/block17_3/Branch_1/Conv2d_0c_7x1/weights:0 into inception_b3_7x1_2
# ('TF conv_layer shape: ', (7, 1, 128, 128))
# ('Caffe conv_layer shape: ', (128, 128, 7, 1))
# (u'InceptionResnetV1/Repeat_1/block17_3/Branch_1/Conv2d_0c_7x1', ' copying BN layer params')
# Copying InceptionResnetV1/Repeat_1/block17_10/Conv2d_1x1/weights:0 into inception_b10_1x1_a
# ('TF conv_layer shape: ', (1, 1, 256, 896))
# ('Caffe conv_layer shape: ', (896, 256, 1, 1))
# Copying Biases InceptionResnetV1/Repeat_1/block17_10/Conv2d_1x1/biases:0 into inception_b10_1x1_a
# Copying InceptionResnetV1/Repeat_1/block17_8/Branch_1/Conv2d_0a_1x1/weights:0 into inception_b8_1x7_2_reduce
# ('TF conv_layer shape: ', (1, 1, 896, 128))
# ('Caffe conv_layer shape: ', (128, 896, 1, 1))
# (u'InceptionResnetV1/Repeat_1/block17_8/Branch_1/Conv2d_0a_1x1', ' copying BN layer params')
# Copying InceptionResnetV1/Repeat/block35_5/Conv2d_1x1/weights:0 into inception_a5_1x1
# ('TF conv_layer shape: ', (1, 1, 96, 256))
# ('Caffe conv_layer shape: ', (256, 96, 1, 1))
# Copying Biases InceptionResnetV1/Repeat/block35_5/Conv2d_1x1/biases:0 into inception_a5_1x1
# Copying InceptionResnetV1/Repeat_1/block17_3/Conv2d_1x1/weights:0 into inception_b3_1x1_a
# ('TF conv_layer shape: ', (1, 1, 256, 896))
# ('Caffe conv_layer shape: ', (896, 256, 1, 1))
# Copying Biases InceptionResnetV1/Repeat_1/block17_3/Conv2d_1x1/biases:0 into inception_b3_1x1_a
# Copying InceptionResnetV1/Repeat_1/block17_4/Branch_1/Conv2d_0b_1x7/weights:0 into inception_b4_1x7_2
# ('TF conv_layer shape: ', (1, 7, 128, 128))
# ('Caffe conv_layer shape: ', (128, 128, 1, 7))
# (u'InceptionResnetV1/Repeat_1/block17_4/Branch_1/Conv2d_0b_1x7', ' copying BN layer params')
# Copying InceptionResnetV1/Mixed_7a/Branch_1/Conv2d_1a_3x3/weights:0 into reduction_b_3x3_1
# ('TF conv_layer shape: ', (3, 3, 256, 256))
# ('Caffe conv_layer shape: ', (256, 256, 3, 3))
# (u'InceptionResnetV1/Mixed_7a/Branch_1/Conv2d_1a_3x3', ' copying BN layer params')
# Copying InceptionResnetV1/Repeat_2/block8_3/Conv2d_1x1/weights:0 into inception_c3_1x1_3
# ('TF conv_layer shape: ', (1, 1, 384, 1792))
# ('Caffe conv_layer shape: ', (1792, 384, 1, 1))
# Copying Biases InceptionResnetV1/Repeat_2/block8_3/Conv2d_1x1/biases:0 into inception_c3_1x1_3
# Copying InceptionResnetV1/Mixed_7a/Branch_2/Conv2d_1a_3x3/weights:0 into reduction_b_3x3_2a
# ('TF conv_layer shape: ', (3, 3, 256, 256))
# ('Caffe conv_layer shape: ', (256, 256, 3, 3))
# (u'InceptionResnetV1/Mixed_7a/Branch_2/Conv2d_1a_3x3', ' copying BN layer params')
# Copying InceptionResnetV1/Repeat/block35_4/Branch_2/Conv2d_0a_1x1/weights:0 into inception_a4_1x1_b2
# ('TF conv_layer shape: ', (1, 1, 256, 32))
# ('Caffe conv_layer shape: ', (32, 256, 1, 1))
# (u'InceptionResnetV1/Repeat/block35_4/Branch_2/Conv2d_0a_1x1', ' copying BN layer params')
# Copying InceptionResnetV1/Repeat_2/block8_5/Branch_0/Conv2d_1x1/weights:0 into inception_c5_1x1
# ('TF conv_layer shape: ', (1, 1, 1792, 192))
# ('Caffe conv_layer shape: ', (192, 1792, 1, 1))
# (u'InceptionResnetV1/Repeat_2/block8_5/Branch_0/Conv2d_1x1', ' copying BN layer params')
# Copying InceptionResnetV1/Conv2d_2a_3x3/weights:0 into conv2_3x3_s1
# ('TF conv_layer shape: ', (3, 3, 32, 32))
# ('Caffe conv_layer shape: ', (32, 32, 3, 3))
# (u'InceptionResnetV1/Conv2d_2a_3x3', ' copying BN layer params')
# Copying InceptionResnetV1/Repeat_1/block17_5/Branch_1/Conv2d_0b_1x7/weights:0 into inception_b5_1x7_2
# ('TF conv_layer shape: ', (1, 7, 128, 128))
# ('Caffe conv_layer shape: ', (128, 128, 1, 7))
# (u'InceptionResnetV1/Repeat_1/block17_5/Branch_1/Conv2d_0b_1x7', ' copying BN layer params')
# Copying InceptionResnetV1/Repeat_1/block17_7/Branch_1/Conv2d_0a_1x1/weights:0 into inception_b7_1x7_2_reduce
# ('TF conv_layer shape: ', (1, 1, 896, 128))
# ('Caffe conv_layer shape: ', (128, 896, 1, 1))
# (u'InceptionResnetV1/Repeat_1/block17_7/Branch_1/Conv2d_0a_1x1', ' copying BN layer params')
# Copying InceptionResnetV1/Repeat/block35_5/Branch_2/Conv2d_0a_1x1/weights:0 into inception_a5_1x1_b2
# ('TF conv_layer shape: ', (1, 1, 256, 32))
# ('Caffe conv_layer shape: ', (32, 256, 1, 1))
# (u'InceptionResnetV1/Repeat/block35_5/Branch_2/Conv2d_0a_1x1', ' copying BN layer params')
# Copying InceptionResnetV1/Mixed_7a/Branch_0/Conv2d_1a_3x3/weights:0 into reduction_b_3x3
# ('TF conv_layer shape: ', (3, 3, 256, 384))
# ('Caffe conv_layer shape: ', (384, 256, 3, 3))
# (u'InceptionResnetV1/Mixed_7a/Branch_0/Conv2d_1a_3x3', ' copying BN layer params')
# Copying InceptionResnetV1/Repeat_1/block17_3/Branch_1/Conv2d_0b_1x7/weights:0 into inception_b3_1x7_2
# ('TF conv_layer shape: ', (1, 7, 128, 128))
# ('Caffe conv_layer shape: ', (128, 128, 1, 7))
# (u'InceptionResnetV1/Repeat_1/block17_3/Branch_1/Conv2d_0b_1x7', ' copying BN layer params')
# Copying InceptionResnetV1/Repeat_1/block17_6/Branch_1/Conv2d_0c_7x1/weights:0 into inception_b6_7x1_2
# ('TF conv_layer shape: ', (7, 1, 128, 128))
# ('Caffe conv_layer shape: ', (128, 128, 7, 1))
# (u'InceptionResnetV1/Repeat_1/block17_6/Branch_1/Conv2d_0c_7x1', ' copying BN layer params')
# Copying InceptionResnetV1/Repeat/block35_2/Conv2d_1x1/weights:0 into inception_a2_1x1
# ('TF conv_layer shape: ', (1, 1, 96, 256))
# ('Caffe conv_layer shape: ', (256, 96, 1, 1))
# Copying Biases InceptionResnetV1/Repeat/block35_2/Conv2d_1x1/biases:0 into inception_a2_1x1
# Copying InceptionResnetV1/Mixed_6a/Branch_1/Conv2d_0a_1x1/weights:0 into reduction_a_conv_1x1_reduce
# ('TF conv_layer shape: ', (1, 1, 256, 192))
# ('Caffe conv_layer shape: ', (192, 256, 1, 1))
# (u'InceptionResnetV1/Mixed_6a/Branch_1/Conv2d_0a_1x1', ' copying BN layer params')
# Copying InceptionResnetV1/Repeat_1/block17_9/Branch_0/Conv2d_1x1/weights:0 into inception_b9_1x1
# ('TF conv_layer shape: ', (1, 1, 896, 128))
# ('Caffe conv_layer shape: ', (128, 896, 1, 1))
# (u'InceptionResnetV1/Repeat_1/block17_9/Branch_0/Conv2d_1x1', ' copying BN layer params')
# Copying InceptionResnetV1/Repeat_2/block8_3/Branch_1/Conv2d_0b_1x3/weights:0 into inception_c3_1x3_2
# ('TF conv_layer shape: ', (1, 3, 192, 192))
# ('Caffe conv_layer shape: ', (192, 192, 1, 3))
# (u'InceptionResnetV1/Repeat_2/block8_3/Branch_1/Conv2d_0b_1x3', ' copying BN layer params')
# Copying InceptionResnetV1/Repeat/block35_3/Branch_1/Conv2d_0a_1x1/weights:0 into inception_a3_1x1_b1
# ('TF conv_layer shape: ', (1, 1, 256, 32))
# ('Caffe conv_layer shape: ', (32, 256, 1, 1))
# (u'InceptionResnetV1/Repeat/block35_3/Branch_1/Conv2d_0a_1x1', ' copying BN layer params')
# Copying InceptionResnetV1/Repeat_1/block17_3/Branch_1/Conv2d_0a_1x1/weights:0 into inception_b3_1x7_2_reduce
# ('TF conv_layer shape: ', (1, 1, 896, 128))
# ('Caffe conv_layer shape: ', (128, 896, 1, 1))
# (u'InceptionResnetV1/Repeat_1/block17_3/Branch_1/Conv2d_0a_1x1', ' copying BN layer params')
# Copying InceptionResnetV1/Repeat_2/block8_5/Conv2d_1x1/weights:0 into inception_c5_1x1_3
# ('TF conv_layer shape: ', (1, 1, 384, 1792))
# ('Caffe conv_layer shape: ', (1792, 384, 1, 1))
# Copying Biases InceptionResnetV1/Repeat_2/block8_5/Conv2d_1x1/biases:0 into inception_c5_1x1_3
# Copying InceptionResnetV1/Repeat_2/block8_3/Branch_1/Conv2d_0c_3x1/weights:0 into inception_c3_3x1_2
# ('TF conv_layer shape: ', (3, 1, 192, 192))
# ('Caffe conv_layer shape: ', (192, 192, 3, 1))
# (u'InceptionResnetV1/Repeat_2/block8_3/Branch_1/Conv2d_0c_3x1', ' copying BN layer params')
# Copying InceptionResnetV1/Repeat_1/block17_7/Branch_0/Conv2d_1x1/weights:0 into inception_b7_1x1
# ('TF conv_layer shape: ', (1, 1, 896, 128))
# ('Caffe conv_layer shape: ', (128, 896, 1, 1))
# (u'InceptionResnetV1/Repeat_1/block17_7/Branch_0/Conv2d_1x1', ' copying BN layer params')
# Copying InceptionResnetV1/Repeat_2/block8_1/Branch_0/Conv2d_1x1/weights:0 into inception_c1_1x1
# ('TF conv_layer shape: ', (1, 1, 1792, 192))
# ('Caffe conv_layer shape: ', (192, 1792, 1, 1))
# (u'InceptionResnetV1/Repeat_2/block8_1/Branch_0/Conv2d_1x1', ' copying BN layer params')
# Copying InceptionResnetV1/Repeat/block35_3/Branch_0/Conv2d_1x1/weights:0 into inception_a3_1x1_b0
# ('TF conv_layer shape: ', (1, 1, 256, 32))
# ('Caffe conv_layer shape: ', (32, 256, 1, 1))
# (u'InceptionResnetV1/Repeat/block35_3/Branch_0/Conv2d_1x1', ' copying BN layer params')
# Copying InceptionResnetV1/Repeat/block35_1/Branch_1/Conv2d_0b_3x3/weights:0 into inception_a1_3x3_b1
# ('TF conv_layer shape: ', (3, 3, 32, 32))
# ('Caffe conv_layer shape: ', (32, 32, 3, 3))
# (u'InceptionResnetV1/Repeat/block35_1/Branch_1/Conv2d_0b_3x3', ' copying BN layer params')
# Copying InceptionResnetV1/Repeat_1/block17_5/Branch_1/Conv2d_0c_7x1/weights:0 into inception_b5_7x1_2
# ('TF conv_layer shape: ', (7, 1, 128, 128))
# ('Caffe conv_layer shape: ', (128, 128, 7, 1))
# (u'InceptionResnetV1/Repeat_1/block17_5/Branch_1/Conv2d_0c_7x1', ' copying BN layer params')
# Copying InceptionResnetV1/Repeat/block35_5/Branch_1/Conv2d_0b_3x3/weights:0 into inception_a5_3x3_b1
# ('TF conv_layer shape: ', (3, 3, 32, 32))
# ('Caffe conv_layer shape: ', (32, 32, 3, 3))
# (u'InceptionResnetV1/Repeat/block35_5/Branch_1/Conv2d_0b_3x3', ' copying BN layer params')
# Copying InceptionResnetV1/Repeat_1/block17_2/Conv2d_1x1/weights:0 into inception_b2_1x1_a
# ('TF conv_layer shape: ', (1, 1, 256, 896))
# ('Caffe conv_layer shape: ', (896, 256, 1, 1))
# Copying Biases InceptionResnetV1/Repeat_1/block17_2/Conv2d_1x1/biases:0 into inception_b2_1x1_a
# Copying InceptionResnetV1/Repeat_1/block17_1/Branch_0/Conv2d_1x1/weights:0 into inception_b1_1x1
# ('TF conv_layer shape: ', (1, 1, 896, 128))
# ('Caffe conv_layer shape: ', (128, 896, 1, 1))
# (u'InceptionResnetV1/Repeat_1/block17_1/Branch_0/Conv2d_1x1', ' copying BN layer params')
# Copying InceptionResnetV1/Mixed_6a/Branch_0/Conv2d_1a_3x3/weights:0 into reduction_a_conv_3x3
# ('TF conv_layer shape: ', (3, 3, 256, 384))
# ('Caffe conv_layer shape: ', (384, 256, 3, 3))
# (u'InceptionResnetV1/Mixed_6a/Branch_0/Conv2d_1a_3x3', ' copying BN layer params')
# Copying InceptionResnetV1/Mixed_7a/Branch_1/Conv2d_0a_1x1/weights:0 into reduction_b_3x3_reduce_1
# ('TF conv_layer shape: ', (1, 1, 896, 256))
# ('Caffe conv_layer shape: ', (256, 896, 1, 1))
# (u'InceptionResnetV1/Mixed_7a/Branch_1/Conv2d_0a_1x1', ' copying BN layer params')
# Copying InceptionResnetV1/Repeat_1/block17_1/Branch_1/Conv2d_0c_7x1/weights:0 into inception_b1_7x1_2
# ('TF conv_layer shape: ', (7, 1, 128, 128))
# ('Caffe conv_layer shape: ', (128, 128, 7, 1))
# (u'InceptionResnetV1/Repeat_1/block17_1/Branch_1/Conv2d_0c_7x1', ' copying BN layer params')
# Copying InceptionResnetV1/Conv2d_2b_3x3/weights:0 into conv3_3x3_s1
# ('TF conv_layer shape: ', (3, 3, 32, 64))
# ('Caffe conv_layer shape: ', (64, 32, 3, 3))
# (u'InceptionResnetV1/Conv2d_2b_3x3', ' copying BN layer params')
# Copying InceptionResnetV1/Repeat_1/block17_8/Branch_1/Conv2d_0c_7x1/weights:0 into inception_b8_7x1_2
# ('TF conv_layer shape: ', (7, 1, 128, 128))
# ('Caffe conv_layer shape: ', (128, 128, 7, 1))
# (u'InceptionResnetV1/Repeat_1/block17_8/Branch_1/Conv2d_0c_7x1', ' copying BN layer params')
# Copying InceptionResnetV1/Conv2d_1a_3x3/weights:0 into conv1_3x3_s2
# ('TF conv_layer shape: ', (3, 3, 3, 32))
# ('Caffe conv_layer shape: ', (32, 3, 3, 3))
# (u'InceptionResnetV1/Conv2d_1a_3x3', ' copying BN layer params')
# Copying InceptionResnetV1/Block8/Branch_1/Conv2d_0c_3x1/weights:0 into Block8_conv_3x1_2
# ('TF conv_layer shape: ', (3, 1, 192, 192))
# ('Caffe conv_layer shape: ', (192, 192, 3, 1))
# (u'InceptionResnetV1/Block8/Branch_1/Conv2d_0c_3x1', ' copying BN layer params')
# Copying InceptionResnetV1/Repeat_2/block8_2/Branch_0/Conv2d_1x1/weights:0 into inception_c2_1x1
# ('TF conv_layer shape: ', (1, 1, 1792, 192))
# ('Caffe conv_layer shape: ', (192, 1792, 1, 1))
# (u'InceptionResnetV1/Repeat_2/block8_2/Branch_0/Conv2d_1x1', ' copying BN layer params')
# Copying InceptionResnetV1/Repeat_1/block17_10/Branch_1/Conv2d_0c_7x1/weights:0 into inception_b10_7x1_2
# ('TF conv_layer shape: ', (7, 1, 128, 128))
# ('Caffe conv_layer shape: ', (128, 128, 7, 1))
# (u'InceptionResnetV1/Repeat_1/block17_10/Branch_1/Conv2d_0c_7x1', ' copying BN layer params')
# Copying InceptionResnetV1/Repeat/block35_4/Branch_0/Conv2d_1x1/weights:0 into inception_a4_1x1_b0
# ('TF conv_layer shape: ', (1, 1, 256, 32))
# ('Caffe conv_layer shape: ', (32, 256, 1, 1))
# (u'InceptionResnetV1/Repeat/block35_4/Branch_0/Conv2d_1x1', ' copying BN layer params')
# Copying InceptionResnetV1/Repeat_1/block17_4/Branch_1/Conv2d_0c_7x1/weights:0 into inception_b4_7x1_2
# ('TF conv_layer shape: ', (7, 1, 128, 128))
# ('Caffe conv_layer shape: ', (128, 128, 7, 1))
# (u'InceptionResnetV1/Repeat_1/block17_4/Branch_1/Conv2d_0c_7x1', ' copying BN layer params')
# Copying InceptionResnetV1/Mixed_7a/Branch_2/Conv2d_0b_3x3/weights:0 into reduction_b_3x3_2
# ('TF conv_layer shape: ', (3, 3, 256, 256))
# ('Caffe conv_layer shape: ', (256, 256, 3, 3))
# (u'InceptionResnetV1/Mixed_7a/Branch_2/Conv2d_0b_3x3', ' copying BN layer params')
# Copying InceptionResnetV1/Repeat_1/block17_8/Conv2d_1x1/weights:0 into inception_b8_1x1_a
# ('TF conv_layer shape: ', (1, 1, 256, 896))
# ('Caffe conv_layer shape: ', (896, 256, 1, 1))
# Copying Biases InceptionResnetV1/Repeat_1/block17_8/Conv2d_1x1/biases:0 into inception_b8_1x1_a
# Copying InceptionResnetV1/Repeat_1/block17_5/Conv2d_1x1/weights:0 into inception_b5_1x1_a
# ('TF conv_layer shape: ', (1, 1, 256, 896))
# ('Caffe conv_layer shape: ', (896, 256, 1, 1))
# Copying Biases InceptionResnetV1/Repeat_1/block17_5/Conv2d_1x1/biases:0 into inception_b5_1x1_a
# Copying InceptionResnetV1/Repeat_2/block8_1/Branch_1/Conv2d_0b_1x3/weights:0 into inception_c1_1x3_2
# ('TF conv_layer shape: ', (1, 3, 192, 192))
# ('Caffe conv_layer shape: ', (192, 192, 1, 3))
# (u'InceptionResnetV1/Repeat_2/block8_1/Branch_1/Conv2d_0b_1x3', ' copying BN layer params')
# Copying InceptionResnetV1/Repeat/block35_5/Branch_2/Conv2d_0c_3x3/weights:0 into inception_a5_3x3_b2_a
# ('TF conv_layer shape: ', (3, 3, 32, 32))
# ('Caffe conv_layer shape: ', (32, 32, 3, 3))
# (u'InceptionResnetV1/Repeat/block35_5/Branch_2/Conv2d_0c_3x3', ' copying BN layer params')
# Copying InceptionResnetV1/Repeat_1/block17_1/Branch_1/Conv2d_0a_1x1/weights:0 into inception_b1_1x7_2_reduce
# ('TF conv_layer shape: ', (1, 1, 896, 128))
# ('Caffe conv_layer shape: ', (128, 896, 1, 1))
# (u'InceptionResnetV1/Repeat_1/block17_1/Branch_1/Conv2d_0a_1x1', ' copying BN layer params')
# Copying InceptionResnetV1/Block8/Branch_1/Conv2d_0b_1x3/weights:0 into Block8_conv_1x3_2
# ('TF conv_layer shape: ', (1, 3, 192, 192))
# ('Caffe conv_layer shape: ', (192, 192, 1, 3))
# (u'InceptionResnetV1/Block8/Branch_1/Conv2d_0b_1x3', ' copying BN layer params')
# Copying InceptionResnetV1/Repeat_2/block8_2/Conv2d_1x1/weights:0 into inception_c2_1x1_3
# ('TF conv_layer shape: ', (1, 1, 384, 1792))
# ('Caffe conv_layer shape: ', (1792, 384, 1, 1))
# Copying Biases InceptionResnetV1/Repeat_2/block8_2/Conv2d_1x1/biases:0 into inception_c2_1x1_3
# Copying InceptionResnetV1/Repeat_1/block17_9/Branch_1/Conv2d_0a_1x1/weights:0 into inception_b9_1x7_2_reduce
# ('TF conv_layer shape: ', (1, 1, 896, 128))
# ('Caffe conv_layer shape: ', (128, 896, 1, 1))
# (u'InceptionResnetV1/Repeat_1/block17_9/Branch_1/Conv2d_0a_1x1', ' copying BN layer params')
# Copying InceptionResnetV1/Repeat/block35_5/Branch_1/Conv2d_0a_1x1/weights:0 into inception_a5_1x1_b1
# ('TF conv_layer shape: ', (1, 1, 256, 32))
# ('Caffe conv_layer shape: ', (32, 256, 1, 1))
# (u'InceptionResnetV1/Repeat/block35_5/Branch_1/Conv2d_0a_1x1', ' copying BN layer params')
# Copying InceptionResnetV1/Repeat_1/block17_2/Branch_1/Conv2d_0c_7x1/weights:0 into inception_b2_7x1_2
# ('TF conv_layer shape: ', (7, 1, 128, 128))
# ('Caffe conv_layer shape: ', (128, 128, 7, 1))
# (u'InceptionResnetV1/Repeat_1/block17_2/Branch_1/Conv2d_0c_7x1', ' copying BN layer params')
# Copying InceptionResnetV1/Repeat_2/block8_4/Branch_1/Conv2d_0b_1x3/weights:0 into inception_c4_1x3_2
# ('TF conv_layer shape: ', (1, 3, 192, 192))
# ('Caffe conv_layer shape: ', (192, 192, 1, 3))
# (u'InceptionResnetV1/Repeat_2/block8_4/Branch_1/Conv2d_0b_1x3', ' copying BN layer params')
# Copying InceptionResnetV1/Repeat/block35_5/Branch_0/Conv2d_1x1/weights:0 into inception_a5_1x1_b0
# ('TF conv_layer shape: ', (1, 1, 256, 32))
# ('Caffe conv_layer shape: ', (32, 256, 1, 1))
# (u'InceptionResnetV1/Repeat/block35_5/Branch_0/Conv2d_1x1', ' copying BN layer params')
# Copying InceptionResnetV1/Repeat_1/block17_2/Branch_0/Conv2d_1x1/weights:0 into inception_b2_1x1
# ('TF conv_layer shape: ', (1, 1, 896, 128))
# ('Caffe conv_layer shape: ', (128, 896, 1, 1))
# (u'InceptionResnetV1/Repeat_1/block17_2/Branch_0/Conv2d_1x1', ' copying BN layer params')
# Copying InceptionResnetV1/Mixed_6a/Branch_1/Conv2d_0b_3x3/weights:0 into reduction_a_conv_3x3_2
# ('TF conv_layer shape: ', (3, 3, 192, 192))
# ('Caffe conv_layer shape: ', (192, 192, 3, 3))
# (u'InceptionResnetV1/Mixed_6a/Branch_1/Conv2d_0b_3x3', ' copying BN layer params')
# Copying InceptionResnetV1/Repeat_2/block8_5/Branch_1/Conv2d_0c_3x1/weights:0 into inception_c5_3x1_2
# ('TF conv_layer shape: ', (3, 1, 192, 192))
# ('Caffe conv_layer shape: ', (192, 192, 3, 1))
# (u'InceptionResnetV1/Repeat_2/block8_5/Branch_1/Conv2d_0c_3x1', ' copying BN layer params')
# Copying InceptionResnetV1/Repeat/block35_4/Branch_2/Conv2d_0b_3x3/weights:0 into inception_a4_3x3_b2
# ('TF conv_layer shape: ', (3, 3, 32, 32))
# ('Caffe conv_layer shape: ', (32, 32, 3, 3))
# (u'InceptionResnetV1/Repeat/block35_4/Branch_2/Conv2d_0b_3x3', ' copying BN layer params')
# Copying InceptionResnetV1/Repeat_1/block17_9/Conv2d_1x1/weights:0 into inception_b9_1x1_a
# ('TF conv_layer shape: ', (1, 1, 256, 896))
# ('Caffe conv_layer shape: ', (896, 256, 1, 1))
# Copying Biases InceptionResnetV1/Repeat_1/block17_9/Conv2d_1x1/biases:0 into inception_b9_1x1_a
# Copying InceptionResnetV1/Repeat_2/block8_3/Branch_0/Conv2d_1x1/weights:0 into inception_c3_1x1
# ('TF conv_layer shape: ', (1, 1, 1792, 192))
# ('Caffe conv_layer shape: ', (192, 1792, 1, 1))
# (u'InceptionResnetV1/Repeat_2/block8_3/Branch_0/Conv2d_1x1', ' copying BN layer params')
# Copying InceptionResnetV1/Repeat_2/block8_4/Branch_0/Conv2d_1x1/weights:0 into inception_c4_1x1
# ('TF conv_layer shape: ', (1, 1, 1792, 192))
# ('Caffe conv_layer shape: ', (192, 1792, 1, 1))
# (u'InceptionResnetV1/Repeat_2/block8_4/Branch_0/Conv2d_1x1', ' copying BN layer params')
# Copying InceptionResnetV1/Repeat_1/block17_6/Branch_0/Conv2d_1x1/weights:0 into inception_b6_1x1
# ('TF conv_layer shape: ', (1, 1, 896, 128))
# ('Caffe conv_layer shape: ', (128, 896, 1, 1))
# (u'InceptionResnetV1/Repeat_1/block17_6/Branch_0/Conv2d_1x1', ' copying BN layer params')
# Copying InceptionResnetV1/Repeat_2/block8_3/Branch_1/Conv2d_0a_1x1/weights:0 into inception_c3_1x1_2
# ('TF conv_layer shape: ', (1, 1, 1792, 192))
# ('Caffe conv_layer shape: ', (192, 1792, 1, 1))
# (u'InceptionResnetV1/Repeat_2/block8_3/Branch_1/Conv2d_0a_1x1', ' copying BN layer params')
# Copying InceptionResnetV1/Repeat_1/block17_9/Branch_1/Conv2d_0b_1x7/weights:0 into inception_b9_1x7_2
# ('TF conv_layer shape: ', (1, 7, 128, 128))
# ('Caffe conv_layer shape: ', (128, 128, 1, 7))
# (u'InceptionResnetV1/Repeat_1/block17_9/Branch_1/Conv2d_0b_1x7', ' copying BN layer params')
# Copying InceptionResnetV1/Repeat_1/block17_10/Branch_1/Conv2d_0a_1x1/weights:0 into inception_b10_1x7_2_reduce
# ('TF conv_layer shape: ', (1, 1, 896, 128))
# ('Caffe conv_layer shape: ', (128, 896, 1, 1))
# (u'InceptionResnetV1/Repeat_1/block17_10/Branch_1/Conv2d_0a_1x1', ' copying BN layer params')
# Copying InceptionResnetV1/Repeat_1/block17_6/Branch_1/Conv2d_0a_1x1/weights:0 into inception_b6_1x7_2_reduce
# ('TF conv_layer shape: ', (1, 1, 896, 128))
# ('Caffe conv_layer shape: ', (128, 896, 1, 1))
# (u'InceptionResnetV1/Repeat_1/block17_6/Branch_1/Conv2d_0a_1x1', ' copying BN layer params')
# Copying InceptionResnetV1/Repeat_1/block17_9/Branch_1/Conv2d_0c_7x1/weights:0 into inception_b9_7x1_2
# ('TF conv_layer shape: ', (7, 1, 128, 128))
# ('Caffe conv_layer shape: ', (128, 128, 7, 1))
# (u'InceptionResnetV1/Repeat_1/block17_9/Branch_1/Conv2d_0c_7x1', ' copying BN layer params')
# Copying InceptionResnetV1/Repeat_1/block17_10/Branch_1/Conv2d_0b_1x7/weights:0 into inception_b10_1x7_2
# ('TF conv_layer shape: ', (1, 7, 128, 128))
# ('Caffe conv_layer shape: ', (128, 128, 1, 7))
# (u'InceptionResnetV1/Repeat_1/block17_10/Branch_1/Conv2d_0b_1x7', ' copying BN layer params')
# Copying InceptionResnetV1/Block8/Branch_1/Conv2d_0a_1x1/weights:0 into Block8_conv_1x1_2
# ('TF conv_layer shape: ', (1, 1, 1792, 192))
# ('Caffe conv_layer shape: ', (192, 1792, 1, 1))
# (u'InceptionResnetV1/Block8/Branch_1/Conv2d_0a_1x1', ' copying BN layer params')
# Copying InceptionResnetV1/Repeat/block35_3/Branch_2/Conv2d_0c_3x3/weights:0 into inception_a3_3x3_b2_a
# ('TF conv_layer shape: ', (3, 3, 32, 32))
# ('Caffe conv_layer shape: ', (32, 32, 3, 3))
# (u'InceptionResnetV1/Repeat/block35_3/Branch_2/Conv2d_0c_3x3', ' copying BN layer params')
# Copying InceptionResnetV1/Repeat_1/block17_8/Branch_1/Conv2d_0b_1x7/weights:0 into inception_b8_1x7_2
# ('TF conv_layer shape: ', (1, 7, 128, 128))
# ('Caffe conv_layer shape: ', (128, 128, 1, 7))
# (u'InceptionResnetV1/Repeat_1/block17_8/Branch_1/Conv2d_0b_1x7', ' copying BN layer params')
# Copying InceptionResnetV1/Repeat/block35_2/Branch_1/Conv2d_0a_1x1/weights:0 into inception_a2_1x1_b1
# ('TF conv_layer shape: ', (1, 1, 256, 32))
# ('Caffe conv_layer shape: ', (32, 256, 1, 1))
# (u'InceptionResnetV1/Repeat/block35_2/Branch_1/Conv2d_0a_1x1', ' copying BN layer params')
# Copying InceptionResnetV1/Repeat/block35_1/Branch_0/Conv2d_1x1/weights:0 into inception_a1_1x1_b0
# ('TF conv_layer shape: ', (1, 1, 256, 32))
# ('Caffe conv_layer shape: ', (32, 256, 1, 1))
# (u'InceptionResnetV1/Repeat/block35_1/Branch_0/Conv2d_1x1', ' copying BN layer params')
# Copying InceptionResnetV1/Repeat_1/block17_3/Branch_0/Conv2d_1x1/weights:0 into inception_b3_1x1
# ('TF conv_layer shape: ', (1, 1, 896, 128))
# ('Caffe conv_layer shape: ', (128, 896, 1, 1))
# (u'InceptionResnetV1/Repeat_1/block17_3/Branch_0/Conv2d_1x1', ' copying BN layer params')
# Copying InceptionResnetV1/Repeat/block35_1/Branch_2/Conv2d_0a_1x1/weights:0 into inception_a1_1x1_b2
# ('TF conv_layer shape: ', (1, 1, 256, 32))
# ('Caffe conv_layer shape: ', (32, 256, 1, 1))
# (u'InceptionResnetV1/Repeat/block35_1/Branch_2/Conv2d_0a_1x1', ' copying BN layer params')
# Copying InceptionResnetV1/Repeat_2/block8_4/Conv2d_1x1/weights:0 into inception_c4_1x1_3
# ('TF conv_layer shape: ', (1, 1, 384, 1792))
# ('Caffe conv_layer shape: ', (1792, 384, 1, 1))
# Copying Biases InceptionResnetV1/Repeat_2/block8_4/Conv2d_1x1/biases:0 into inception_c4_1x1_3
# Copying InceptionResnetV1/Conv2d_3b_1x1/weights:0 into conv4_1x1_s1
# ('TF conv_layer shape: ', (1, 1, 64, 80))
# ('Caffe conv_layer shape: ', (80, 64, 1, 1))
# (u'InceptionResnetV1/Conv2d_3b_1x1', ' copying BN layer params')
# Copying InceptionResnetV1/Repeat/block35_5/Branch_2/Conv2d_0b_3x3/weights:0 into inception_a5_3x3_b2
# ('TF conv_layer shape: ', (3, 3, 32, 32))
# ('Caffe conv_layer shape: ', (32, 32, 3, 3))
# (u'InceptionResnetV1/Repeat/block35_5/Branch_2/Conv2d_0b_3x3', ' copying BN layer params')
# Copying InceptionResnetV1/Repeat_2/block8_5/Branch_1/Conv2d_0a_1x1/weights:0 into inception_c5_1x1_2
# ('TF conv_layer shape: ', (1, 1, 1792, 192))
# ('Caffe conv_layer shape: ', (192, 1792, 1, 1))
# (u'InceptionResnetV1/Repeat_2/block8_5/Branch_1/Conv2d_0a_1x1', ' copying BN layer params')
# Copying InceptionResnetV1/Repeat_1/block17_5/Branch_1/Conv2d_0a_1x1/weights:0 into inception_b5_1x7_2_reduce
# ('TF conv_layer shape: ', (1, 1, 896, 128))
# ('Caffe conv_layer shape: ', (128, 896, 1, 1))
# (u'InceptionResnetV1/Repeat_1/block17_5/Branch_1/Conv2d_0a_1x1', ' copying BN layer params')
# Copying InceptionResnetV1/Block8/Branch_0/Conv2d_1x1/weights:0 into Block8_conv_1x1
# ('TF conv_layer shape: ', (1, 1, 1792, 192))
# ('Caffe conv_layer shape: ', (192, 1792, 1, 1))
# (u'InceptionResnetV1/Block8/Branch_0/Conv2d_1x1', ' copying BN layer params')
# Copying InceptionResnetV1/Repeat_1/block17_4/Conv2d_1x1/weights:0 into inception_b4_1x1_a
# ('TF conv_layer shape: ', (1, 1, 256, 896))
# ('Caffe conv_layer shape: ', (896, 256, 1, 1))
# Copying Biases InceptionResnetV1/Repeat_1/block17_4/Conv2d_1x1/biases:0 into inception_b4_1x1_a
# Copying InceptionResnetV1/Repeat/block35_1/Branch_2/Conv2d_0b_3x3/weights:0 into inception_a1_3x3_b2
# ('TF conv_layer shape: ', (3, 3, 32, 32))
# ('Caffe conv_layer shape: ', (32, 32, 3, 3))
# (u'InceptionResnetV1/Repeat/block35_1/Branch_2/Conv2d_0b_3x3', ' copying BN layer params')
# Copying InceptionResnetV1/Repeat/block35_2/Branch_1/Conv2d_0b_3x3/weights:0 into inception_a2_3x3_b1
# ('TF conv_layer shape: ', (3, 3, 32, 32))
# ('Caffe conv_layer shape: ', (32, 32, 3, 3))
# (u'InceptionResnetV1/Repeat/block35_2/Branch_1/Conv2d_0b_3x3', ' copying BN layer params')
# Copying InceptionResnetV1/Repeat/block35_4/Branch_1/Conv2d_0b_3x3/weights:0 into inception_a4_3x3_b1
# ('TF conv_layer shape: ', (3, 3, 32, 32))
# ('Caffe conv_layer shape: ', (32, 32, 3, 3))
# (u'InceptionResnetV1/Repeat/block35_4/Branch_1/Conv2d_0b_3x3', ' copying BN layer params')
# Copying InceptionResnetV1/Repeat_1/block17_1/Conv2d_1x1/weights:0 into inception_b1_1x1_a
# ('TF conv_layer shape: ', (1, 1, 256, 896))
# ('Caffe conv_layer shape: ', (896, 256, 1, 1))
# Copying Biases InceptionResnetV1/Repeat_1/block17_1/Conv2d_1x1/biases:0 into inception_b1_1x1_a
# Copying InceptionResnetV1/Mixed_7a/Branch_2/Conv2d_0a_1x1/weights:0 into reduction_b_3x3_reduce_2
# ('TF conv_layer shape: ', (1, 1, 896, 256))
# ('Caffe conv_layer shape: ', (256, 896, 1, 1))
# (u'InceptionResnetV1/Mixed_7a/Branch_2/Conv2d_0a_1x1', ' copying BN layer params')
# Copying InceptionResnetV1/Repeat_1/block17_10/Branch_0/Conv2d_1x1/weights:0 into inception_b10_1x1
# ('TF conv_layer shape: ', (1, 1, 896, 128))
# ('Caffe conv_layer shape: ', (128, 896, 1, 1))
# (u'InceptionResnetV1/Repeat_1/block17_10/Branch_0/Conv2d_1x1', ' copying BN layer params')
# Copying InceptionResnetV1/Repeat_1/block17_2/Branch_1/Conv2d_0a_1x1/weights:0 into inception_b2_1x7_2_reduce
# ('TF conv_layer shape: ', (1, 1, 896, 128))
# ('Caffe conv_layer shape: ', (128, 896, 1, 1))
# (u'InceptionResnetV1/Repeat_1/block17_2/Branch_1/Conv2d_0a_1x1', ' copying BN layer params')
# Copying InceptionResnetV1/Repeat_1/block17_7/Branch_1/Conv2d_0b_1x7/weights:0 into inception_b7_1x7_2
# ('TF conv_layer shape: ', (1, 7, 128, 128))
# ('Caffe conv_layer shape: ', (128, 128, 1, 7))
# (u'InceptionResnetV1/Repeat_1/block17_7/Branch_1/Conv2d_0b_1x7', ' copying BN layer params')
# Copying InceptionResnetV1/Repeat/block35_2/Branch_2/Conv2d_0c_3x3/weights:0 into inception_a2_3x3_b2_a
# ('TF conv_layer shape: ', (3, 3, 32, 32))
# ('Caffe conv_layer shape: ', (32, 32, 3, 3))
# (u'InceptionResnetV1/Repeat/block35_2/Branch_2/Conv2d_0c_3x3', ' copying BN layer params')
# Copying InceptionResnetV1/Repeat_2/block8_2/Branch_1/Conv2d_0c_3x1/weights:0 into inception_c2_3x1_2
# ('TF conv_layer shape: ', (3, 1, 192, 192))
# ('Caffe conv_layer shape: ', (192, 192, 3, 1))
# (u'InceptionResnetV1/Repeat_2/block8_2/Branch_1/Conv2d_0c_3x1', ' copying BN layer params')
# Copying InceptionResnetV1/Repeat/block35_4/Branch_1/Conv2d_0a_1x1/weights:0 into inception_a4_1x1_b1
# ('TF conv_layer shape: ', (1, 1, 256, 32))
# ('Caffe conv_layer shape: ', (32, 256, 1, 1))
# (u'InceptionResnetV1/Repeat/block35_4/Branch_1/Conv2d_0a_1x1', ' copying BN layer params')
# Copying InceptionResnetV1/Repeat/block35_1/Branch_2/Conv2d_0c_3x3/weights:0 into inception_a1_3x3_b2_a
# ('TF conv_layer shape: ', (3, 3, 32, 32))
# ('Caffe conv_layer shape: ', (32, 32, 3, 3))
# (u'InceptionResnetV1/Repeat/block35_1/Branch_2/Conv2d_0c_3x3', ' copying BN layer params')
# Copying InceptionResnetV1/Repeat_1/block17_7/Conv2d_1x1/weights:0 into inception_b7_1x1_a
# ('TF conv_layer shape: ', (1, 1, 256, 896))
# ('Caffe conv_layer shape: ', (896, 256, 1, 1))
# Copying Biases InceptionResnetV1/Repeat_1/block17_7/Conv2d_1x1/biases:0 into inception_b7_1x1_a
# Copying InceptionResnetV1/Repeat_2/block8_2/Branch_1/Conv2d_0b_1x3/weights:0 into inception_c2_1x3_2
# ('TF conv_layer shape: ', (1, 3, 192, 192))
# ('Caffe conv_layer shape: ', (192, 192, 1, 3))
# (u'InceptionResnetV1/Repeat_2/block8_2/Branch_1/Conv2d_0b_1x3', ' copying BN layer params')
# Copying InceptionResnetV1/Repeat/block35_3/Branch_2/Conv2d_0a_1x1/weights:0 into inception_a3_1x1_b2
# ('TF conv_layer shape: ', (1, 1, 256, 32))
# ('Caffe conv_layer shape: ', (32, 256, 1, 1))
# (u'InceptionResnetV1/Repeat/block35_3/Branch_2/Conv2d_0a_1x1', ' copying BN layer params')
# Copying InceptionResnetV1/Repeat_2/block8_1/Conv2d_1x1/weights:0 into inception_c1_1x1_3
# ('TF conv_layer shape: ', (1, 1, 384, 1792))
# ('Caffe conv_layer shape: ', (1792, 384, 1, 1))
# Copying Biases InceptionResnetV1/Repeat_2/block8_1/Conv2d_1x1/biases:0 into inception_c1_1x1_3
# Copying InceptionResnetV1/Repeat_1/block17_4/Branch_0/Conv2d_1x1/weights:0 into inception_b4_1x1
# ('TF conv_layer shape: ', (1, 1, 896, 128))
# ('Caffe conv_layer shape: ', (128, 896, 1, 1))
# (u'InceptionResnetV1/Repeat_1/block17_4/Branch_0/Conv2d_1x1', ' copying BN layer params')
# Copying InceptionResnetV1/Repeat_1/block17_1/Branch_1/Conv2d_0b_1x7/weights:0 into inception_b1_1x7_2
# ('TF conv_layer shape: ', (1, 7, 128, 128))
# ('Caffe conv_layer shape: ', (128, 128, 1, 7))
# (u'InceptionResnetV1/Repeat_1/block17_1/Branch_1/Conv2d_0b_1x7', ' copying BN layer params')
# Copying InceptionResnetV1/Repeat_2/block8_5/Branch_1/Conv2d_0b_1x3/weights:0 into inception_c5_1x3_2
# ('TF conv_layer shape: ', (1, 3, 192, 192))
# ('Caffe conv_layer shape: ', (192, 192, 1, 3))
# (u'InceptionResnetV1/Repeat_2/block8_5/Branch_1/Conv2d_0b_1x3', ' copying BN layer params')
# Copying InceptionResnetV1/Repeat_1/block17_2/Branch_1/Conv2d_0b_1x7/weights:0 into inception_b2_1x7_2
# ('TF conv_layer shape: ', (1, 7, 128, 128))
# ('Caffe conv_layer shape: ', (128, 128, 1, 7))
# (u'InceptionResnetV1/Repeat_1/block17_2/Branch_1/Conv2d_0b_1x7', ' copying BN layer params')
# Copying InceptionResnetV1/Repeat/block35_4/Conv2d_1x1/weights:0 into inception_a4_1x1
# ('TF conv_layer shape: ', (1, 1, 96, 256))
# ('Caffe conv_layer shape: ', (256, 96, 1, 1))
# Copying Biases InceptionResnetV1/Repeat/block35_4/Conv2d_1x1/biases:0 into inception_a4_1x1
# Copying InceptionResnetV1/Repeat/block35_4/Branch_2/Conv2d_0c_3x3/weights:0 into inception_a4_3x3_b2_a
# ('TF conv_layer shape: ', (3, 3, 32, 32))
# ('Caffe conv_layer shape: ', (32, 32, 3, 3))
# (u'InceptionResnetV1/Repeat/block35_4/Branch_2/Conv2d_0c_3x3', ' copying BN layer params')
# Copying InceptionResnetV1/Mixed_6a/Branch_1/Conv2d_1a_3x3/weights:0 into reduction_a_conv_3x3_3
# ('TF conv_layer shape: ', (3, 3, 192, 256))
# ('Caffe conv_layer shape: ', (256, 192, 3, 3))
# (u'InceptionResnetV1/Mixed_6a/Branch_1/Conv2d_1a_3x3', ' copying BN layer params')
# Copying InceptionResnetV1/Repeat_1/block17_5/Branch_0/Conv2d_1x1/weights:0 into inception_b5_1x1
# ('TF conv_layer shape: ', (1, 1, 896, 128))
# ('Caffe conv_layer shape: ', (128, 896, 1, 1))
# (u'InceptionResnetV1/Repeat_1/block17_5/Branch_0/Conv2d_1x1', ' copying BN layer params')
# Copying InceptionResnetV1/Repeat_2/block8_4/Branch_1/Conv2d_0a_1x1/weights:0 into inception_c4_1x1_2
# ('TF conv_layer shape: ', (1, 1, 1792, 192))
# ('Caffe conv_layer shape: ', (192, 1792, 1, 1))
# (u'InceptionResnetV1/Repeat_2/block8_4/Branch_1/Conv2d_0a_1x1', ' copying BN layer params')

# %%
new_caffe_net.save('/home/caffe/achu/models/facenet_ccna_inc_resnet_v1.caffemodel')

# %%
#Debugging from here
caffe_net = caffe.Net('/home/ovuser/Projects/tf_2_caffe/facenet_deploy.prototxt', 'inc_resnet_v1_facenet_latest_5_15.caffemodel', caffe.TEST)

# %%
def check_params(tf_names, caffe_names, caffe_net, model_dir = '/home/ovuser/FaceRecognition/models/20170512-110547'):
    with tf.Graph().as_default():
        with tf.Session() as sess:
            facenet.load_model(model_dir)
            all_tensors = tf.contrib.graph_editor.get_tensors(tf.get_default_graph())
            all_tensor_names = [tensor.name for tensor in all_tensors]
            features_tensor_index = all_tensor_names.index('InceptionResnetV1/Bottleneck/weights:0')
            features_value = all_tensors[features_tensor_index].eval()
            if not np.array_equal(caffe_net.params['features'][0].data, features_value.transpose((1,0))):
                print ('Mismatch features layer')
            for i in range(len(caffe_names)):
                caffe_name = caffe_names[i]
                tf_conv_layer_name = tf_names[i]+'/weights:0'
                tf_conv_name_index = all_tensor_names.index(tf_conv_layer_name)
                tf_conv_layer_tensor = all_tensors[tf_conv_name_index]
                #print ('Copying ' + tf_conv_layer_tensor.name+' into '+caffe_name)
                conv_layer_value = tf_conv_layer_tensor.eval()
                if (caffe_net.params[caffe_name][0].data.shape == conv_layer_value.transpose((3,2,1,0)).shape):
                    print (np.array_equal(caffe_net.params[caffe_name][0].data,conv_layer_value.transpose((3,2,1,0))))
                elif (caffe_net.params[caffe_name][0].data.shape == conv_layer_value.transpose((3,2,0,1)).shape):
                    print (np.array_equal(caffe_net.params[caffe_name][0].data,conv_layer_value.transpose((3,2,0,1))))
                else:
                    print ('Shape mismatch: ', caffe_name, caffe_net.params[caffe_name][0].data.shape, conv_layer_value.shape)
                
                if (re.match('InceptionResnetV1/Repeat_1/block17_\d+/Conv2d_1x1', tf_names[i].encode("ascii")) is None) and (re.match('InceptionResnetV1/Repeat/block35_\d/Conv2d_1x1', tf_names[i].encode("ascii")) is None) and (re.match('InceptionResnetV1/Block8/Conv2d_1x1', tf_names[i].encode("ascii")) is None) and (re.match('InceptionResnetV1/Repeat_2/block8_\d/Conv2d_1x1', tf_names[i].encode("ascii")) is None):
                    #print (tf_names[i], ' copying BN layer params')
                    tf_bn_layer_name_1 = tf_names[i]+'/BatchNorm/moving_mean:0'
                    tf_bn_layer_name_2 = tf_names[i]+'/BatchNorm/moving_variance:0' #+0.001
                    #tf_bn_layer_name_3 to be set to one
                    #tf_scale_layer_name_1 to be set to one Gamma
                    tf_scale_layer_name_2 = tf_names[i]+'/BatchNorm/beta:0'
                    caffe_bn_layer_name = caffe_name + '_bn'
                    caffe_scale_layer_name = caffe_name + '_scale'


                    tf_bn_name_index_1 = all_tensor_names.index(tf_bn_layer_name_1)
                    tf_bn_name_index_2 = all_tensor_names.index(tf_bn_layer_name_2)
                    tf_scale_name_index_2 = all_tensor_names.index(tf_scale_layer_name_2)


                    tf_bn_layer_1_tensor = all_tensors[tf_bn_name_index_1]
                    tf_bn_layer_2_tensor = all_tensors[tf_bn_name_index_2]
                    tf_scale_layer_2_tensor = all_tensors[tf_scale_name_index_2]


                    bn_layer_1_value = tf_bn_layer_1_tensor.eval()
                    bn_layer_2_value = tf_bn_layer_2_tensor.eval() + 0.00001
                    bn_layer_3_value = np.ones(caffe_net.params[caffe_bn_layer_name][2].data.shape)
                    scale_layer_1_value = np.ones(caffe_net.params[caffe_scale_layer_name][0].data.shape)
                    scale_layer_2_value = tf_scale_layer_2_tensor.eval()
                    
                    #print ('Beta: ', scale_layer_2_value)

                    #Actual copy operations

                    #print (caffe_net.params[caffe_bn_layer_name][0].data.shape, bn_layer_1_value.shape)
                    if not np.array_equal(caffe_net.params[caffe_bn_layer_name][0].data, bn_layer_1_value):
                        print ('Mismatch bn_layer_1: ', caffe_name)

                    #print (caffe_net.params[caffe_bn_layer_name][1].data.shape, bn_layer_2_value.shape)
                    if not np.array_equal(caffe_net.params[caffe_bn_layer_name][1].data, bn_layer_2_value):
                        print ('Mismatch bn_layer_2: ', caffe_name)

                    #print (caffe_net.params[caffe_bn_layer_name][2].data.shape, bn_layer_3_value.shape)
                    if not np.array_equal(caffe_net.params[caffe_bn_layer_name][2].data, bn_layer_3_value):
                        print ('Mismatch bn_layer_3: ', caffe_name)

                    #print (caffe_net.params[caffe_scale_layer_name][0].data.shape, scale_layer_1_value.shape)
                    if not np.array_equal(caffe_net.params[caffe_scale_layer_name][0].data, scale_layer_1_value):
                        print ('Mismatch scale_layer_1: ', caffe_name)

                    #print (caffe_net.params[caffe_scale_layer_name][1].data.shape, scale_layer_2_value.shape)
                    if not np.array_equal(caffe_net.params[caffe_scale_layer_name][1].data, scale_layer_2_value):
                        print ('Mismatch scale_layer_2: ', caffe_name)

# %%
print ('drop' in caffe_net.params.keys())
